# %% [markdown]
# <a href="https://colab.research.google.com/github/dlozano55/remolabs-test/blob/main/CK_Case_Study_Diego_Lozano.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install db-dtypes google google-cloud google-cloud-bigquery google-auth

# %%
import json
with open('/content/ck-sp-case-study-2024-2aef28547e77.json', 'r') as json_file:
    data = json.load(json_file)

# %%
data
# Out:
# {'type': 'service_account',
#  'project_id': 'ck-sp-case-study-2024',
#  'private_key_id': '2aef28547e7793d07c7868837e167337aac66bc1',
# ...

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
def read_bigquery_data(query,data):
    # Create a BigQuery client instance
    credentials = service_account.Credentials.from_service_account_info(data)
    client = bigquery.Client(credentials=credentials)

    # Execute the query and retrieve the results as a pandas DataFrame
    query_job = client.query(query)
    dataframe = query_job.to_dataframe()

    return dataframe

# %%
query=""" SELECT * FROM `ck-sp-case-study-2024.case_study.orders`"""
read_bigquery_data(query,data)
# Out:
#              DATE                                 Facility  \
# 0      2023-08-25                        NA-US-TX-KOL-18th
# 1      2023-09-04                        NA-US-TX-KOL-18th
# 2      2023-09-04                        NA-US-TX-KOL-18th
# 3      2023-09-03                        NA-US-TX-KOL-18th
# 4      2023-09-03                        NA-US-TX-KOL-18th
# ...           ...                                      ...
# 49995  2023-08-21         NA-US-TUCS-SA-Lombrano (Correct)
# 49996  2023-08-31  NA-US-NG-OTT-Tempe (Kitchens) (correct)
# 49997  2023-08-30  NA-US-NG-OTT-Tempe (Kitchens) (correct)
# 49998  2023-08-11  NA-US-NG-OTT-Tempe (Kitchens) (correct)
# 49999  2023-08-29  NA-US-NG-OTT-Tempe (Kitchens) (correct)
#
#                                 Facility_id  organization_name  is_cancelled  \
# 0      40cb78af-5b18-4044-82af-8751b9c34b58       boring river         False
# 1      40cb78af-5b18-4044-82af-8751b9c34b58      tactful yacht         False
# ...
